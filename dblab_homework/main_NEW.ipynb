# %%
import pandas as pd

pd.set_option('display.max_columns', None)  # Tüm sütunları göster

# %%
df = pd.read_csv("cleaned_dataset_FINAL.csv")
df.head()
# Out:
# C:\Users\alica\AppData\Local\Temp\ipykernel_9256\108603707.py:1: DtypeWarning: Columns (12,23,25,29,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("cleaned_dataset_FINAL.csv")
#    Basvuru Yili  Degerlendirme Puani Cinsiyet  Dogum Yeri Ikametgah Sehri  \
# 0          2014                 52.0    erkek      ankara          ankara
# 1          2014                 30.0    erkek    istanbul        istanbul
# 2          2014                 18.0    erkek      samsun        istanbul
# 3          2014                 40.0    erkek  diyarbakir        istanbul
# 4          2014                 24.0    erkek      ankara          ankara
#
#                      Universite Adi Universite Turu  Burslu ise Burs Yuzdesi  \
# 0           ihsan dogramaci bilkent            ozel                    100.0
# 1           ihsan dogramaci bilkent            ozel                    100.0
# 2  uluslararasi kibris universitesi            ozel                    100.0
# 3       istanbul sehir universitesi            ozel                    100.0
# 4          turgut ozal universitesi            ozel                    100.0
#
#   Burs Aliyor mu?                                     Bölüm  \
# 0            evet                   bilgisayar muhendisligi
# 1           hayir          elektrik elektronik muhendisligi
# 2           hayir              finans yonetimi ve pazarlama
# 3            evet                   bilgisayar muhendisligi
# 4            evet  siyaset bilimi ve uluslararasi iliskiler
#
#   Universite Kacinci Sinif Universite Not Ortalamasi  \
# 0                        3               3.50 - 4.00
# 1                        3               2.50 - 3.00
# 2                        1                       NaN
# 3                        3               2.50 - 3.00
# 4                      NaN               2.50 - 3.00
#
#   Daha Once Baska Bir Universiteden Mezun Olmus  \
# 0                                         hayir
# 1                                         hayir
# 2                                         hayir
# 3                                         hayir
# 4                                         hayir
#
#                         Lise Adi  Lise Sehir       Lise Turu  \
# 0  ankara ataturk anadolu lisesi      ankara  anadolu lisesi
# 1       betul can anadolu lisesi      ankara  anadolu lisesi
# 2                          batem      ankara   meslek lisesi
# 3          cumhuriyet fen lisesi  diyarbakir      fen lisesi
# 4               samanyolu lisesi      ankara       ozel lise
#
#   Baska Bir Kurumdan Burs Aliyor mu? Anne Egitim Durumu Anne Calisma Durumu  \
# 0                              hayir         universite               hayir
# 1                              hayir         universite                evet
# 2                              hayir            ilkokul               hayir
# 3                              hayir            ilkokul               hayir
# 4                              hayir            ilkokul               hayir
#
#   Anne Sektor     Baba Egitim Durumu Baba Calisma Durumu  Baba Sektor  \
# 0  calismiyor             universite              emekli   calismiyor
# 1        kamu  yuksek lisans/doktora              emekli   calismiyor
# 2  calismiyor                ilkokul                evet  ozel sektor
# 3  calismiyor             universite              emekli   calismiyor
# 4  calismiyor             universite              emekli   calismiyor
#
#   Kardes Sayisi Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?  \
# 0             1                                               evet
# 1             1                                              hayir
# 2             6                                               evet
# 3            10                                               evet
# 4             1                                              hayir
#
#                           Uye Oldugunuz Kulubun Ismi  \
# 0  bilkent ieee bilgisayar toplulugu 2013-2014 ba...
# 1                                                NaN
# 2                                               tema
# 3                      guzel konusma ve yazma kulubu
# 4                                                NaN
#
#   Profesyonel Bir Spor Daliyla Mesgul musunuz? Spor Dalindaki Rolunuz Nedir?  \
# 0                                         evet                         diger
# 1                                        hayir                    bilinmiyor
# 2                                        hayir                    bilinmiyor
# 3                                        hayir                    bilinmiyor
# 4                                        hayir                    bilinmiyor
#
#   Aktif olarak bir STK üyesi misiniz? Stk Projesine Katildiniz Mi?  \
# 0                               hayir                         evet
# 1                               hayir                         evet
# 2                               hayir                        hayir
# 3                               hayir                         evet
# 4                               hayir                        hayir
#
#   Girisimcilikle Ilgili Deneyiminiz Var Mi? Ingilizce Biliyor musunuz?  \
# 0                                     hayir                        NaN
# 1                                      evet                        NaN
# 2                                     hayir                        NaN
# 3                                     hayir                        NaN
# 4                                     hayir                        NaN
#
#   Burslu ise Burs Yuzdesi Aralik  Dogum Yili   Yas
# 0                         90-100      1994.0  30.0
# 1                         90-100      1993.0  31.0
# 2                         90-100      1986.0  38.0
# 3                         90-100      1991.0  33.0
# 4                         90-100      1992.0  32.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65125 entries, 0 to 65124
# Data columns (total 35 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Basvuru Yili                                          65125 non-null  int64
#  1   Degerlendirme Puani                                   65124 non-null  float64
#  2   Cinsiyet                                              64956 non-null  object
#  3   Dogum Yeri                                            65125 non-null  object
#  4   Ikametgah Sehri                                       63088 non-null  object
#  5   Universite Adi                                        64993 non-null  object
#  6   Universite Turu                                       64870 non-null  object
#  7   Burslu ise Burs Yuzdesi                               22440 non-null  float64
#  8   Burs Aliyor mu?                                       65125 non-null  object
#  9   Bölüm                                                 64894 non-null  object
#  10  Universite Kacinci Sinif                              64751 non-null  object
#  11  Universite Not Ortalamasi                             62372 non-null  object
#  12  Daha Once Baska Bir Universiteden Mezun Olmus         27780 non-null  object
#  13  Lise Adi                                              64741 non-null  object
#  14  Lise Sehir                                            65125 non-null  object
#  15  Lise Turu                                             64278 non-null  object
#  16  Baska Bir Kurumdan Burs Aliyor mu?                    64894 non-null  object
#  17  Anne Egitim Durumu                                    64719 non-null  object
#  18  Anne Calisma Durumu                                   53229 non-null  object
#  19  Anne Sektor                                           30588 non-null  object
#  20  Baba Egitim Durumu                                    64118 non-null  object
#  21  Baba Calisma Durumu                                   52507 non-null  object
#  22  Baba Sektor                                           44747 non-null  object
#  23  Kardes Sayisi                                         63993 non-null  object
#  24  Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?  63296 non-null  object
#  25  Uye Oldugunuz Kulubun Ismi                            16434 non-null  object
#  26  Profesyonel Bir Spor Daliyla Mesgul musunuz?          64010 non-null  object
#  27  Spor Dalindaki Rolunuz Nedir?                         32850 non-null  object
#  28  Aktif olarak bir STK üyesi misiniz?                   52283 non-null  object
#  29  Stk Projesine Katildiniz Mi?                          36817 non-null  object
#  30  Girisimcilikle Ilgili Deneyiminiz Var Mi?             52285 non-null  object
#  31  Ingilizce Biliyor musunuz?                            58671 non-null  object
#  32  Burslu ise Burs Yuzdesi Aralik                        22440 non-null  object
#  33  Dogum Yili                                            39379 non-null  float64
#  34  Yas                                                   39379 non-null  float64
# dtypes: float64(4), int64(1), object(30)
# memory usage: 17.4+ MB

# %%
df = df.drop(columns=['Lise Adi', 'Lise Sehir','Lise Turu'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65125 entries, 0 to 65124
# Data columns (total 32 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Basvuru Yili                                          65125 non-null  int64
#  1   Degerlendirme Puani                                   65124 non-null  float64
#  2   Cinsiyet                                              64956 non-null  object
#  3   Dogum Yeri                                            65125 non-null  object
#  4   Ikametgah Sehri                                       63088 non-null  object
#  5   Universite Adi                                        64993 non-null  object
#  6   Universite Turu                                       64870 non-null  object
#  7   Burslu ise Burs Yuzdesi                               22440 non-null  float64
#  8   Burs Aliyor mu?                                       65125 non-null  object
#  9   Bölüm                                                 64894 non-null  object
#  10  Universite Kacinci Sinif                              64751 non-null  object
#  11  Universite Not Ortalamasi                             62372 non-null  object
#  12  Daha Once Baska Bir Universiteden Mezun Olmus         27780 non-null  object
#  13  Baska Bir Kurumdan Burs Aliyor mu?                    64894 non-null  object
#  14  Anne Egitim Durumu                                    64719 non-null  object
#  15  Anne Calisma Durumu                                   53229 non-null  object
#  16  Anne Sektor                                           30588 non-null  object
#  17  Baba Egitim Durumu                                    64118 non-null  object
#  18  Baba Calisma Durumu                                   52507 non-null  object
#  19  Baba Sektor                                           44747 non-null  object
#  20  Kardes Sayisi                                         63993 non-null  object
#  21  Girisimcilik Kulupleri Tarzi Bir Kulube Uye misiniz?  63296 non-null  object
#  22  Uye Oldugunuz Kulubun Ismi                            16434 non-null  object
#  23  Profesyonel Bir Spor Daliyla Mesgul musunuz?          64010 non-null  object
#  24  Spor Dalindaki Rolunuz Nedir?                         32850 non-null  object
#  25  Aktif olarak bir STK üyesi misiniz?                   52283 non-null  object
#  26  Stk Projesine Katildiniz Mi?                          36817 non-null  object
#  27  Girisimcilikle Ilgili Deneyiminiz Var Mi?             52285 non-null  object
#  28  Ingilizce Biliyor musunuz?                            58671 non-null  object
#  29  Burslu ise Burs Yuzdesi Aralik                        22440 non-null  object
#  30  Dogum Yili                                            39379 non-null  float64
#  31  Yas                                                   39379 non-null  float64
# dtypes: float64(4), int64(1), object(27)
# memory usage: 15.9+ MB

# %% [markdown]
# STUDENT
#     student id
#     cinsiyet
#     doğum yeri
#     ikametgah
#     dogum yil
#     yaş
# UNI
#     uni id
#     uni tür
# STUDENT ACADEMIC INFO
#     bölüm
#     unı kacıncı sınıf
#     not ortalama
#     daha pnce unı mezun olmus mu
# FAMILY
#     anne eğitim
#     anne calısma durumu
#     baba eğitim
#     anne sektor
#     baba çalışma durumu
#     baba sektor
#     kardeş sayısı
# NGO
#     sivil toplum kuruluş üye misin
#     proje katıldın mı
#
#
# SCHOLARSHIP
#     burslu ise yüzde
#     burs alıyorm u
#     başka kurum burs alıyor mu
#
# SPORT
#     profesyonel spor dalı var mı
#     rolunuz ne
#
# ENRETEPERENEURSHIP
#     deneyim vamı
#     kulub uyersi misin
#     uye oldugunuz kulup adıa
#
# başvuru bilgi
#     başvuu yılı
#     değerlendirme puanı

# %%
def how_many_types(dataframe, col_name):
    
    diff_types = set(dataframe[col_name].apply(type))
    num_of_diff_types =len(diff_types)
    print(f"Sütunda {num_of_diff_types} farklı veri tipi var: {diff_types} ")

# Bütün harfleri küçük yapma
def all_letters_lowered(dataframe, col_name):
    """
    Belirtilen bir sütundaki tüm string değerleri küçük harfe çevirir.
    
    Parametreler:
    dataframe (pd.DataFrame): İşlem yapılacak DataFrame.
    col_name (str): Tüm string değerlerinin küçük harfe çevrileceği sütunun adı.
    
    İşlev:
    - Verilen sütundaki tüm string ifadeler `.str.lower()` ile küçük harfe dönüştürülür.
    
    Not:
    - Bu fonksiyon doğrudan orijinal DataFrame üzerinde değişiklik yapar (`inplace=True` gibi davranır).
    
    Örnek kullanım:
    all_letters_lowered(df, 'column_name')
    """
    dataframe[col_name] = dataframe[col_name].str.lower()


# Eşsiz değerleri ve NaN değerleri görme
def values_and_nulls(dataframe, col_name):
    """
    Belirtilen bir sütundaki eşsiz değerleri ve NaN değerlerinin sayısını gösterir.
    
    Parametreler:
    dataframe (pd.DataFrame): İşlem yapılacak DataFrame.
    col_name (str): Eşsiz değerlerin ve NaN değerlerinin sayısının hesaplanacağı sütun adı.
    
    İşlev:
    1. Sütundaki eşsiz değerleri ve bu değerlerin kaç kere tekrar ettiğini gösterir.
    2. Sütundaki NaN (eksik) değerlerin sayısını gösterir.
    
    Çıktı:
    - Sütundaki eşsiz değerlerin sıklığı.
    - NaN değerlerin sayısı.
    """
    print(dataframe[col_name].value_counts(), end="\n\n")
    print("NaN: ", dataframe[col_name].isnull().sum())

# %%
values_and_nulls(df, "Baska Bir Kurumdan Burs Aliyor mu?")
# Out:
# Baska Bir Kurumdan Burs Aliyor mu?
# hayir    48513
# evet     16381
# Name: count, dtype: int64
#
# NaN:  231

# %%
import csv

# Girdi ve çıktı dosyalarının isimleri
input_file = 'veriler.csv'  # Mevcut dosya adı
output_file = 'temizlenmis_veriler.csv'  # Yeni oluşturulacak dosya adı

# Dosyayı aç ve işle
with open(input_file, mode='r', encoding='utf-8') as infile:
    reader = csv.reader(infile)
    rows = []
    for row in reader:
        # 13., 14. ve 15. sütunları sil (indexler: 13, 14, 15)
        # Silme işlemi öncesi kontrol yapılabilir
        if len(row) > 15:  # En az 16 sütun varsa sil
            del row[13:16]
        rows.append(row)

# Yeni dosyaya yaz
with open(output_file, mode='w', encoding='utf-8', newline='') as outfile:
    writer = csv.writer(outfile)
    writer.writerows(rows)

print(f"İşlem tamamlandı. Yeni dosya '{output_file}' olarak kaydedildi.")
